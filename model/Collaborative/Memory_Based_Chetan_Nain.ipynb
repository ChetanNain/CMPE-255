# %% [markdown]
# # Memory-Based Collaborative Filtering

# %% [markdown]
# ### Using the provided dataset, we will construct memory-based collaborative filtering in Python. Columns include bookId, UserId, Rating, id, and title.
#
# ### Using UserId, bookId, and Ratings, we'll try to discover people similar to our target user (chosen at random) and propose items to our potential customer recommended products will be the things that similar users have enjoyed in the past.

# %%
from collections import defaultdict
import random
import numpy
import scipy.optimize
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import warnings
warnings.filterwarnings('ignore')

# %%
books_data = pd.read_csv('../../data_preprocessing/books_data.csv')
ratings_data = pd.read_csv('../../data/books_ratings_data.csv')
book_tags_data = pd.read_csv('../../data/book_tags_data.csv')
tags_data = pd.read_csv('../../data/tags_data.csv')

# %%
ratings_data = ratings_data.drop_duplicates()

# %%
dataset = pd.merge(ratings_data, books_data[['id','title']], how='inner', left_on='book_id', right_on='id')

# %%
dataset.head(10)
# Out:
#    book_id  user_id  rating  id                              title
# 0        1      314       5   1  the hunger games the hunger games
# 1        1      439       3   1  the hunger games the hunger games
# 2        1      588       5   1  the hunger games the hunger games
# 3        1     1169       4   1  the hunger games the hunger games
# 4        1     1185       4   1  the hunger games the hunger games
# 5        1     2077       4   1  the hunger games the hunger games
# 6        1     2487       4   1  the hunger games the hunger games
# 7        1     2900       5   1  the hunger games the hunger games
# 8        1     3662       4   1  the hunger games the hunger games
# 9        1     3922       5   1  the hunger games the hunger games

# %% [markdown]
# ### Before we start lets try and find out the unique number of users and books in the dataset.

# %%
unique_users = dataset['user_id'].unique()
print(len(unique_users))
# Out:
# 52895

# %%
unique_bookId= dataset['book_id'].unique()
print(len(unique_bookId))
# Out:
# 9397

# %% [markdown]
# ### So we have around 53,000 unique users reading around 9300 unique books.

# %% [markdown]
# ### Now we will create a new dataframe consisting of all userId in the first column.

# %%
new_df = pd.DataFrame(unique_users)
new_df.columns=['userId']

# %% [markdown]
# ### Next we will create a column for each book in the dataset. This will help us to fill the ratings in the matrix cells given by each user. Similary to a sparse matrix.

# %%
for title in unique_title:
    new_df[title]=None

# %% [markdown]
# ### Finally we will fill the ratings given by each user in the corresponding cells. This indeed will return us a very huge matrix consisting of approximately 53000 x 9300.

# %%
for j,user in enumerate(new_df['userId'].values):
    for i in range(dataset[dataset['user_id']==user].shape[0]):
        title = dataset[dataset['user_id']==user]['title'].iloc[i]
        rating = dataset[dataset['user_id']==user]['rating'].iloc[i]
        new_df[title][j] = rating

# %% [markdown]
# ### Below is the new dataframe consisting of all the ratings.

# %%
new_df.head
# Out:
# <bound method NDFrame.head of        userId the hunger games the hunger games  \
# 0         314                                 5
# 1         439                                 3
# 2         588                                 5
# 3        1169                                 4
# 4        1185                                 4
# ...       ...                               ...
# 52890   52363                              None
# 52891   27590                              None
# 52892   51339                              None
# 52893    9310                              None
# 52894    6532                              None
#
#       harry potter and the sorcerers stone harry potter twilight twilight  \
# 0                                                  None                 3
# 1                                                  None              None
# 2                                                  None                 1
# 3                                                     3              None
# 4                                                  None              None
# ...                                                 ...               ...
# 52890                                              None              None
# 52891                                              None              None
# 52892                                              None              None
# 52893                                              None              None
# 52894                                              None              None
#
#       to kill a mockingbird the great gatsby the fault in our stars  \
# 0                      None                4                      5
# 1                         5             None                   None
# 2                      None             None                   None
# 3                         5                5                   None
# 4                      None             None                   None
# ...                     ...              ...                    ...
# 52890                  None             None                   None
# 52891                  None             None                   None
# 52892                  None             None                   None
# 52893                  None             None                   None
# 52894                  None             None                   None
#
#       the hobbit the catcher in the rye angels demons robert langdon  ...  \
# 0           None                   None                         None  ...
# 1              3                   None                            3  ...
# 2           None                      3                            3  ...
# 3           None                   None                         None  ...
# 4           None                   None                         None  ...
# ...          ...                    ...                          ...  ...
# 52890       None                   None                         None  ...
# 52891       None                   None                         None  ...
# 52892       None                   None                         None  ...
# 52893       None                   None                         None  ...
# 52894       None                   None                         None  ...
#
#       the famished road the red knight the traitor son cycle  \
# 0                  None                                 None
# 1                  None                                 None
# 2                  None                                 None
# 3                  None                                 None
# 4                  None                                 None
# ...                 ...                                  ...
# 52890              None                                 None
# 52891                 4                                    4
# 52892              None                                    4
# 52893              None                                 None
# 52894              None                                 None
#
#       the time travellers guide to medieval england a handbook for visitors to the fourteenth century  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 52890                                               None
# 52891                                               None
# 52892                                               None
# 52893                                               None
# 52894                                               None
#
#       the everafter war the sisters grimm billy budd sailor  \
# 0                                    None              None
# 1                                    None              None
# 2                                    None              None
# 3                                    None              None
# 4                                    None              None
# ...                                   ...               ...
# 52890                                None              None
# 52891                                None              None
# 52892                                None              None
# 52893                                None              None
# 52894                                None              None
#
#       bayou moon the edge means of ascent the years of lyndon johnson  \
# 0                    None                                        None
# 1                    None                                        None
# 2                    None                                        None
# 3                    None                                        None
# 4                    None                                        None
# ...                   ...                                         ...
# 52890                None                                        None
# 52891                None                                        None
# 52892                None                                        None
# 52893                None                                           5
# 52894                None                                        None
#
#       the mauritius command  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ...                     ...
# 52890                  None
# 52891                  None
# 52892                  None
# 52893                  None
# 52894                  None
#
#       cinderella ate my daughter dispatches from the frontlines of the new girlie girl culture  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 52890                                               None
# 52891                                               None
# 52892                                               None
# 52893                                               None
# 52894                                               None
#
#       the first world war
# 0                    None
# 1                    None
# 2                    None
# 3                    None
# 4                    None
# ...                   ...
# 52890                None
# 52891                None
# 52892                None
# 52893                None
# 52894                   4
#
# [52895 rows x 9274 columns]>

# %% [markdown]
# ### Now from the above prepared matrix, we’ll pick a user randomly and find similar users as that of our target user. As we can see out selected user have rated 65 books. Now we will use this data to recommend him books based on the target user who has rated books similarly.

# %%
user = pd.DataFrame(new_df.iloc[2121])
user = user.drop(['userId'])
user[user.notnull().values]
# Out:
# Empty DataFrame
# Columns: [2121]
# Index: []

# %% [markdown]
# ### Printing the head and finding out the userId for getting the similarity

# %%
subset = new_df[new_df[user[user.notnull().values].index[0]].notnull()]
subset.head()
# Out:
#     userId the hunger games the hunger games  \
# 32   17984                                 5
# 38   20848                                 5
# 44   23612                                 4
# 56   28158                                 4
# 86   46977                                 4
#
#    harry potter and the sorcerers stone harry potter twilight twilight  \
# 32                                                 5              None
# 38                                              None                 4
# 44                                                 5                 3
# 56                                              None              None
# 86                                                 3                 2
#
#    to kill a mockingbird the great gatsby the fault in our stars the hobbit  \
# 32                     5             None                      4       None
# 38                  None             None                   None          5
# 44                  None             None                   None       None
# 56                  None                4                      3       None
# 86                  None             None                   None       None
#
#    the catcher in the rye angels demons robert langdon  ... the famished road  \
# 32                   None                            4  ...              None
# 38                      5                         None  ...              None
# 44                   None                            3  ...              None
# 56                      3                         None  ...              None
# 86                   None                            2  ...              None
#
#    the red knight the traitor son cycle  \
# 32                                 None
# 38                                 None
# 44                                 None
# 56                                 None
# 86                                 None
#
#    the time travellers guide to medieval england a handbook for visitors to the fourteenth century  \
# 32                                               None
# 38                                               None
# 44                                               None
# 56                                               None
# 86                                               None
#
#    the everafter war the sisters grimm billy budd sailor bayou moon the edge  \
# 32                                None              None                None
# 38                                None              None                None
# 44                                None              None                None
# 56                                None              None                None
# 86                                None              None                None
#
#    means of ascent the years of lyndon johnson the mauritius command  \
# 32                                        None                  None
# 38                                        None                  None
# 44                                        None                  None
# 56                                        None                  None
# 86                                        None                  None
#
#    cinderella ate my daughter dispatches from the frontlines of the new girlie girl culture  \
# 32                                               None
# 38                                               None
# 44                                               None
# 56                                               None
# 86                                               None
#
#    the first world war
# 32                None
# 38                None
# 44                None
# 56                None
# 86                None
#
# [5 rows x 9274 columns]

# %% [markdown]
# ### After that replacing all the null values with 0 so that we can perform calculations on the numerical values.

# %%
subset = subset.replace([None],0)
subset = subset.set_index('userId')

# %%
subset.head()
# Out:
#         the hunger games the hunger games  \
# userId
# 17984                                   5
# 20848                                   5
# 23612                                   4
# 28158                                   4
# 46977                                   4
#
#         harry potter and the sorcerers stone harry potter  twilight twilight  \
# userId
# 17984                                                   5                  0
# 20848                                                   0                  4
# 23612                                                   5                  3
# 28158                                                   0                  0
# 46977                                                   3                  2
#
#         to kill a mockingbird  the great gatsby  the fault in our stars  \
# userId
# 17984                       5                 0                       4
# 20848                       0                 0                       0
# 23612                       0                 0                       0
# 28158                       0                 4                       3
# 46977                       0                 0                       0
#
#         the hobbit  the catcher in the rye  angels demons robert langdon  \
# userId
# 17984            0                       0                             4
# 20848            5                       5                             0
# 23612            0                       0                             3
# 28158            0                       3                             0
# 46977            0                       0                             2
#
#         pride and prejudice  ...  the famished road  \
# userId                       ...
# 17984                     5  ...                  0
# 20848                     0  ...                  0
# 23612                     4  ...                  0
# 28158                     0  ...                  0
# 46977                     0  ...                  0
#
#         the red knight the traitor son cycle  \
# userId
# 17984                                      0
# 20848                                      0
# 23612                                      0
# 28158                                      0
# 46977                                      0
#
#         the time travellers guide to medieval england a handbook for visitors to the fourteenth century  \
# userId
# 17984                                                   0
# 20848                                                   0
# 23612                                                   0
# 28158                                                   0
# 46977                                                   0
#
#         the everafter war the sisters grimm  billy budd sailor  \
# userId
# 17984                                     0                  0
# 20848                                     0                  0
# 23612                                     0                  0
# 28158                                     0                  0
# 46977                                     0                  0
#
#         bayou moon the edge  means of ascent the years of lyndon johnson  \
# userId
# 17984                     0                                            0
# 20848                     0                                            0
# 23612                     0                                            0
# 28158                     0                                            0
# 46977                     0                                            0
#
#         the mauritius command  \
# userId
# 17984                       0
# 20848                       0
# 23612                       0
# 28158                       0
# 46977                       0
#
#         cinderella ate my daughter dispatches from the frontlines of the new girlie girl culture  \
# userId
# 17984                                                   0
# 20848                                                   0
# 23612                                                   0
# 28158                                                   0
# 46977                                                   0
#
#         the first world war
# userId
# 17984                     0
# 20848                     0
# 23612                     0
# 28158                     0
# 46977                     0
#
# [5 rows x 9273 columns]

# %%
subset['similarity'] = 0.0
for user in subset.index:
    cos = cosine_similarity(subset.loc[28158].values.reshape(1,-1),subset.loc[user].values.reshape(1,-1))
    subset['similarity'][user]=cos

# %% [markdown]
# ### Finally finding out users similar to our selected user.

# %%
subset['similarity']
# Out:
# userId
# 17984    0.181441
# 20848    0.070158
# 23612    0.168881
# 28158    1.000000
# 46977    0.096887
#            ...
# 40772    0.022457
# 41732    0.008473
# 42322    0.023021
# 45989    0.056228
# 51123    0.013671
# Name: similarity, Length: 100, dtype: float64

# %%
# !jupyter nbconvert Memory*.ipynb --to python
# Out:
# [NbConvertApp] Converting notebook Memory_Based_Chetan_Nain.ipynb to python
# [NbConvertApp] Writing 2169 bytes to Memory_Based_Chetan_Nain.py
